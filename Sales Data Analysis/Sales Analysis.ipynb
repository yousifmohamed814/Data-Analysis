# %%
import pandas as pd
import numpy as np

# %%
customers_df=pd.read_csv('D:\Epsilon\scince\Session21(ERD)\data_\data\customers.csv')
products_df=pd.read_csv('D:\Epsilon\scince\Session21(ERD)\data_\data\products.csv')
sals_df=pd.read_csv('D:\Epsilon\scince\Session21(ERD)\data_\data\sales.csv')
orders_df=pd.read_csv('D:\Epsilon\scince\Session21(ERD)\data_\data\orders.csv')

# %%
products_df.head()
# Out:
#    product_ID product_type  product_name size colour  price  quantity  \
# 0           0        Shirt  Oxford Cloth   XS    red    114        66
# 1           1        Shirt  Oxford Cloth    S    red    114        53
# 2           2        Shirt  Oxford Cloth    M    red    114        54
# 3           3        Shirt  Oxford Cloth    L    red    114        69
# 4           4        Shirt  Oxford Cloth   XL    red    114        47
#
#                                     description
# 0  A red coloured, XS sized, Oxford Cloth Shirt
# 1   A red coloured, S sized, Oxford Cloth Shirt
# 2   A red coloured, M sized, Oxford Cloth Shirt
# 3   A red coloured, L sized, Oxford Cloth Shirt
# 4  A red coloured, XL sized, Oxford Cloth Shirt

# %%
products_df['quantityOn_Storage']=products_df['quantity']

# %%
products_df.drop('quantity',axis=1,inplace=True)

# %%
orders_df.head()
# Out:
#    order_id  customer_id  payment order_date delivery_date
# 0         1           64    30811  2021-8-30    2021-09-24
# 1         2          473    50490   2021-2-3    2021-02-13
# 2         3          774    46763  2021-10-8    2021-11-03
# 3         4          433    39782   2021-5-6    2021-05-19
# 4         5          441    14719  2021-3-23    2021-03-24

# %%
customers_df.head()
# Out:
#    customer_id        customer_name       gender  age  \
# 0            1        Leanna Busson       Female   30
# 1            2  Zabrina Harrowsmith  Genderfluid   69
# 2            3      Shina Dullaghan   Polygender   59
# 3            4        Hewet McVitie     Bigender   67
# 4            5       Rubia Ashleigh   Polygender   30
#
#                      home_address  zip_code               city  \
# 0  8606 Victoria TerraceSuite 560      5464      Johnstonhaven
# 1      8327 Kirlin SummitApt. 461      8223    New Zacharyfort
# 2       269 Gemma SummitSuite 109      5661           Aliburgh
# 3       743 Bailey GroveSuite 141      1729  South Justinhaven
# 4         48 Hyatt ManorSuite 375      4032     Griffithsshire
#
#                           state    country
# 0            Northern Territory  Australia
# 1               South Australia  Australia
# 2  Australian Capital Territory  Australia
# 3                    Queensland  Australia
# ...

# %%
sals_df['quantity_Product/Order']=sals_df['quantity']

# %%
sals_df.drop('quantity',axis=1,inplace=True)

# %%
sals_df.head()
# Out:
#    sales_id  order_id  product_id  price_per_unit  total_price  \
# 0         0         1         218             106          212
# 1         1         1         481             118          118
# 2         2         1           2              96          288
# 3         3         1        1002             106          212
# 4         4         1         691             113          339
#
#    quantity_Product/Order
# 0                       2
# 1                       1
# 2                       3
# 3                       2
# 4                       3

# %%
df_Merge1=pd.merge(customers_df,orders_df,how='inner',on='customer_id')
df_Merge1.head()
# Out:
#    customer_id      customer_name    gender  age  \
# 0            1      Leanna Busson    Female   30
# 1            1      Leanna Busson    Female   30
# 2            1      Leanna Busson    Female   30
# 3            7    Winslow Ewbanck  Bigender   76
# 4           10  Susanetta Wilshin  Bigender   70
#
#                      home_address  zip_code           city  \
# 0  8606 Victoria TerraceSuite 560      5464  Johnstonhaven
# 1  8606 Victoria TerraceSuite 560      5464  Johnstonhaven
# 2  8606 Victoria TerraceSuite 560      5464  Johnstonhaven
# 3     92 Hills Station StApt. 683       793      Masonfurt
# 4       615 Hayley KnollSuite 454      2118      Joelburgh
#
#                 state    country  order_id  payment order_date delivery_date
# 0  Northern Territory  Australia       455    24550   2021-4-4    2021-04-06
# 1  Northern Territory  Australia       670    10246   2021-3-6    2021-04-01
# 2  Northern Territory  Australia       729    35593  2021-2-18    2021-03-01
# ...

# %%
products_df.columns=products_df.columns.str.lower()

# %%
df_Merge2=pd.merge(df_Merge1,sals_df,how='inner',on='order_id')
df_Merge2.head()
# Out:
#    customer_id  customer_name  gender  age                    home_address  \
# 0            1  Leanna Busson  Female   30  8606 Victoria TerraceSuite 560
# 1            1  Leanna Busson  Female   30  8606 Victoria TerraceSuite 560
# 2            1  Leanna Busson  Female   30  8606 Victoria TerraceSuite 560
# 3            1  Leanna Busson  Female   30  8606 Victoria TerraceSuite 560
# 4            1  Leanna Busson  Female   30  8606 Victoria TerraceSuite 560
#
#    zip_code           city               state    country  order_id  payment  \
# 0      5464  Johnstonhaven  Northern Territory  Australia       455    24550
# 1      5464  Johnstonhaven  Northern Territory  Australia       455    24550
# 2      5464  Johnstonhaven  Northern Territory  Australia       670    10246
# 3      5464  Johnstonhaven  Northern Territory  Australia       670    10246
# 4      5464  Johnstonhaven  Northern Territory  Australia       670    10246
#
# ...

# %%
df=pd.merge(df_Merge2,products_df,how='inner',on='product_id')
df.head()
# Out:
#    customer_id  customer_name    gender  age                    home_address  \
# 0            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 1            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 2           81  Lanny Wardale    Female   30     4870 Jackson SummitApt. 538
# 3          258  Mira Heinonen    Female   62     2719 Dietrich KnollApt. 175
# 4          432  Ettie Gonnely  Bigender   34      6172 Andrew AvenueApt. 194
#
#    zip_code            city               state    country  order_id  ...  \
# 0      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 1      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 2      1915  Spencerborough   Western Australia  Australia       863  ...
# 3      1252    South Declan          Queensland  Australia       793  ...
# 4      7029      North Cody            Victoria  Australia       939  ...
#
# ...

# %%
df['Remaining_quantity']=df['quantityon_storage'] - df['quantity_Product/Order']

# %%
df.head()
# Out:
#    customer_id  customer_name    gender  age                    home_address  \
# 0            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 1            1  Leanna Busson    Female   30  8606 Victoria TerraceSuite 560
# 2           81  Lanny Wardale    Female   30     4870 Jackson SummitApt. 538
# 3          258  Mira Heinonen    Female   62     2719 Dietrich KnollApt. 175
# 4          432  Ettie Gonnely  Bigender   34      6172 Andrew AvenueApt. 194
#
#    zip_code            city               state    country  order_id  ...  \
# 0      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 1      5464   Johnstonhaven  Northern Territory  Australia       455  ...
# 2      1915  Spencerborough   Western Australia  Australia       863  ...
# 3      1252    South Declan          Queensland  Australia       793  ...
# 4      7029      North Cody            Victoria  Australia       939  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             5000 non-null   int64
#  1   customer_name           5000 non-null   object
#  2   gender                  5000 non-null   object
#  3   age                     5000 non-null   int64
#  4   home_address            5000 non-null   object
#  5   zip_code                5000 non-null   int64
#  6   city                    5000 non-null   object
#  7   state                   5000 non-null   object
#  8   country                 5000 non-null   object
#  9   order_id                5000 non-null   int64
#  10  payment                 5000 non-null   int64
#  11  order_date              5000 non-null   object
#  12  delivery_date           5000 non-null   object
#  13  sales_id                5000 non-null   int64
# ...

# %%
df.describe()
# Out:
#        customer_id          age     zip_code     order_id       payment  \
# count  5000.000000  5000.000000  5000.000000  5000.000000   5000.000000
# mean    504.563000    48.760400  4912.355600   503.038200  33976.785000
# std     276.504896    17.577519  2907.367939   285.964418  14612.706539
# min       1.000000    20.000000    52.000000     1.000000  10043.000000
# 25%     276.000000    34.000000  2273.000000   258.000000  20627.000000
# 50%     509.000000    48.000000  4750.000000   504.500000  34259.000000
# 75%     733.000000    63.000000  7460.250000   749.000000  46608.000000
# max    1000.000000    80.000000  9998.000000   999.000000  59910.000000
#
#           sales_id   product_id  price_per_unit  total_price  \
# count  5000.000000  5000.000000     5000.000000  5000.000000
# mean   2499.500000   634.053200      103.501600   206.360000
# std    1443.520003   363.255794        9.195004    86.357457
# min       0.000000     1.000000       90.000000    90.000000
# ...

# %%
df.shape
# Out:
# (5000, 26)

# %%
df[['customer_id','order_id']].head()
# Out:
#    customer_id  order_id
# 0            1       455
# 1            1       455
# 2           81       863
# 3          258       793
# 4          432       939

# %%
list(df.product_type.unique())
# Out:
# ['Shirt', 'Jacket', 'Trousers']

# %%
df.customer_id.nunique()
# Out:
# 616

# %%
df.order_id.nunique()
# Out:
# 993

# %%
df.product_type.nunique()
# Out:
# 3

# %%
df.city.nunique()
# Out:
# 604

# %%
df.gender.value_counts()
# Out:
# Female         712
# Genderfluid    687
# Male           672
# Genderqueer    647
# Polygender     636
# Non-binary     598
# Agender        526
# Bigender       522
# Name: gender, dtype: int64

# %%
customers_df.gender.value_counts()
# Out:
# Male           143
# Non-binary     131
# Polygender     128
# Genderqueer    127
# Genderfluid    122
# Bigender       120
# Female         115
# Agender        114
# Name: gender, dtype: int64

# %%
df2=df[['customer_id','gender']].drop_duplicates()
df2
# Out:
#       customer_id       gender
# 0               1       Female
# 2              81       Female
# 3             258       Female
# 4             432     Bigender
# 5             944  Genderfluid
# ...           ...          ...
# 4165          951         Male
# 4343          419         Male
# 4382          435      Agender
# 4390          921   Polygender
# 4445          450  Genderfluid
#
# [616 rows x 2 columns]

# %%
df.customer_id.nunique()
# Out:
# 616

# %% [markdown]
# # Active Users

# %%
(df2.gender.value_counts()/df.customer_id.nunique())*100
# Out:
# Genderfluid    14.123377
# Male           13.311688
# Genderqueer    12.824675
# Polygender     12.662338
# Agender        12.337662
# Female         11.850649
# Non-binary     11.688312
# Bigender       11.201299
# Name: gender, dtype: float64

# %%
customers_df.shape
# Out:
# (1000, 9)

# %% [markdown]
# # Total Customers/Gender

# %%
(customers_df.gender.value_counts()/customers_df.shape[0]) * 100
# Out:
# Male           14.3
# Non-binary     13.1
# Polygender     12.8
# Genderqueer    12.7
# Genderfluid    12.2
# Bigender       12.0
# Female         11.5
# Agender        11.4
# Name: gender, dtype: float64

# %% [markdown]
# # Top 5 coustomer ordering

# %%
cust_order_df=df[['customer_id','order_id']].drop_duplicates()

# %%
cust_order_df2=cust_order_df.groupby('customer_id')['order_id'].count().reset_index()
count_order=cust_order_df2.sort_values("order_id",ascending=False).reset_index().drop("index",axis=1)

# %%
count_order
# Out:
#      customer_id  order_id
# 0            571         6
# 1            348         5
# 2            566         5
# 3            664         5
# 4            282         5
# ..           ...       ...
# 611          583         1
# 612          223         1
# 613          578         1
# 614          224         1
# 615         1000         1
#
# [616 rows x 2 columns]

# %%
count_order.columns=['customer_id','order_count']
count_order
# Out:
#      customer_id  order_count
# 0            571            6
# 1            348            5
# 2            566            5
# 3            664            5
# 4            282            5
# ..           ...          ...
# 611          583            1
# 612          223            1
# 613          578            1
# 614          224            1
# 615         1000            1
#
# [616 rows x 2 columns]

# %%
top5=list(count_order.head(5).customer_id.values)

# %%
customers_df[customers_df.customer_id.isin(top5)]
# Out:
#      customer_id    customer_name       gender  age  \
# 281          282     Wren Helgass       Female   59
# 347          348  Thorny Nornable  Genderqueer   76
# 565          566  Melissa Partkya         Male   23
# 570          571   Kristofor Roos      Agender   22
# 663          664    Dannie Fidler  Genderfluid   32
#
#                      home_address  zip_code              city  \
# 281   2634 Ward CrescentSuite 361      4527  Port Hannahburgh
# 347  4070 Nathan CircuitSuite 296      1840          Rubyfort
# 565   95 Rice Station StSuite 985      2919        O'keefeton
# 570      5567 Clarke MallApt. 756      4043        Jordanside
# 663        157 Rohan MallApt. 466      4145          East Max
#
#                             state    country
# 281  Australian Capital Territory  Australia
# 347                      Tasmania  Australia
# 565                      Tasmania  Australia
# 570  Australian Capital Territory  Australia
# 663                      Tasmania  Australia

# %% [markdown]
# # Top 4 cities

# %%
Top_4_customer_cities=list(df[['customer_id','city']].drop_duplicates().city.value_counts().head(4).index)

# %%
Top_4_customer_cities
# Out:
# ['New Ava', 'West Kai', 'East Sophia', 'New Angelina']

# %%
customers_df
# Out:
#      customer_id        customer_name       gender  age  \
# 0              1        Leanna Busson       Female   30
# 1              2  Zabrina Harrowsmith  Genderfluid   69
# 2              3      Shina Dullaghan   Polygender   59
# 3              4        Hewet McVitie     Bigender   67
# 4              5       Rubia Ashleigh   Polygender   30
# ..           ...                  ...          ...  ...
# 995          996       Elvira Sarfati      Agender   59
# 996          997       Dickie Grushin   Non-binary   30
# 997          998       Rebecka Fabler   Polygender   32
# 998          999       Carita Vynarde   Polygender   30
# 999         1000     Mandel Fairbanks         Male   71
#
#                        home_address  zip_code                city  \
# 0    8606 Victoria TerraceSuite 560      5464       Johnstonhaven
# 1        8327 Kirlin SummitApt. 461      8223     New Zacharyfort
# 2         269 Gemma SummitSuite 109      5661            Aliburgh
# ...

# %%
def count_by(col1,col2,v=5):
    """
    col1 : idx
    col2: categoral feature
    """
    return list(df[[col1,col2]].drop_duplicates()[col2].value_counts().head(v).index)

# %%
df[['city','order_id']].drop_duplicates()['order_id'].value_counts()
# Out:
# 999    1
# 327    1
# 341    1
# 340    1
# 339    1
#       ..
# 662    1
# 661    1
# 660    1
# 659    1
# 1      1
# Name: order_id, Length: 993, dtype: int64

# %%
count_by('city','order_id')
# Out:
# [999, 327, 341, 340, 339]

# %%
count_by('customer_id','city',4)
# Out:
# ['New Ava', 'West Kai', 'East Sophia', 'New Angelina', 'Ryanberg']

# %%
count_by('order_id','city')
# Out:
# ['Jordanside', 'New Ava', 'West Kai', 'Lake Rose', 'Rubyfort']

# %%
count_by('order_id','customer_name',10)
# Out:
# ['Kristofor Roos',
#  'Wren Helgass',
#  'Dannie Fidler',
#  'Melissa Partkya',
#  'Thorny Nornable',
#  'Yardley Dreamer',
#  'Sandy Yushachkov',
#  'Phillipe Gatecliffe',
#  'Faber Purcell',
#  'Lin Norville']

# %%
count_by('customer_name','payment',10)#دا عدد ملهوش معنى
# Out:
# [41180, 37821, 18355, 37440, 37878, 43729, 47075, 51250, 31437, 59213]

# %%
count_by('payment','customer_name',10)
# Out:
# ['Kristofor Roos',
#  'Wren Helgass',
#  'Dannie Fidler',
#  'Melissa Partkya',
#  'Thorny Nornable',
#  'Yardley Dreamer',
#  'Sandy Yushachkov',
#  'Phillipe Gatecliffe',
#  'Faber Purcell',
#  'Lin Norville']

# %% [markdown]
# #Top 5 customer payment

# %%
df[['customer_name','payment','order_id']].drop_duplicates().groupby('customer_name').payment.sum()\
.sort_values(ascending=False).head(5).index.to_list()
# Out:
# ['Dannie Fidler',
#  'Melissa Partkya',
#  'Wren Helgass',
#  'Kristofor Roos',
#  'Mallory Castellani']
