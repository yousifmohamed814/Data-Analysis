# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('D:\Epsilon\scince\Session20(ERD)\Assignment datasets\Assignment datasets\BIKES.csv')
df
# Out:
#               datetime  season  holiday  workingday weather   temp  humidity  \
# 0        1/1/2011 0:00  Spring      0.0         0.0   Clear   9.84      81.0
# 1        1/1/2011 0:00  Spring      0.0         0.0     NaN   9.02      80.0
# 2        1/1/2011 0:00  Spring      0.0         0.0   Clear   9.02       NaN
# 3        1/1/2011 0:00  Spring      0.0         0.0   Clear   9.84      75.0
# 4        1/1/2011 0:00     NaN      0.0         0.0   Clear    NaN      75.0
# ...                ...     ...      ...         ...     ...    ...       ...
# 10881  12/19/2012 0:00  Winter      0.0         1.0   Clear  15.58      50.0
# 10882  12/19/2012 0:00  Winter      0.0         1.0     NaN  14.76       NaN
# 10883  12/19/2012 0:00     NaN      0.0         1.0   Clear  13.94      61.0
# 10884  12/19/2012 0:00  Winter      NaN         1.0   Clear  13.94       NaN
# 10885  12/19/2012 0:00  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count
# 0            NaN       3          13                  16
# 1         0.0000       8          32                  40
# 2         0.0000       5          27                  32
# 3         0.0000       3          10                  13
# 4            NaN       0           1                   1
# ...          ...     ...         ...                 ...
# 10881    26.0027       7         329                 336
# 10882        NaN      10         231                 241
# 10883    15.0013       4         164                 168
# 10884     6.0032      12         117                 129
# 10885     8.9981       4          84                  88
#
# [10886 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  object
#  1   season              10672 non-null  object
#  2   holiday             10030 non-null  float64
#  3   workingday          9388 non-null   float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 935.6+ KB

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                856
# workingday            1498
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# dtype: int64

# %% [markdown]
# # Celaning

# %%
df.dropna(axis=0)
# Out:
#               datetime  season  holiday  workingday weather   temp  humidity  \
# 3        1/1/2011 0:00  Spring      0.0         0.0   Clear   9.84      75.0
# 14       1/1/2011 0:00  Spring      0.0         0.0    Mist  18.86      72.0
# 15       1/1/2011 0:00  Spring      0.0         0.0    Mist  18.04      77.0
# 16       1/1/2011 0:00  Spring      0.0         0.0    Mist  17.22      82.0
# 26       1/2/2011 0:00  Spring      0.0         0.0    Mist  17.22     100.0
# ...                ...     ...      ...         ...     ...    ...       ...
# 10844  12/18/2012 0:00  Winter      0.0         1.0   Clear  14.76      93.0
# 10848  12/18/2012 0:00  Winter      0.0         1.0   Clear  18.04      77.0
# 10873  12/19/2012 0:00  Winter      0.0         1.0   Clear  16.40      54.0
# 10881  12/19/2012 0:00  Winter      0.0         1.0   Clear  15.58      50.0
# 10885  12/19/2012 0:00  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count
# 3         0.0000       3          10                  13
# 14       19.0012      35          71                 106
# 15       19.9995      40          70                 110
# 16       19.9995      41          52                  93
# 26       19.0012       1           8                   9
# ...          ...     ...         ...                 ...
# 10844    11.0014       1         117                 118
# 10848     6.0032      22         162                 184
# 10873    15.0013      31         169                 200
# 10881    26.0027       7         329                 336
# 10885     8.9981       4          84                  88
#
# [2177 rows x 11 columns]

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                 214
# holiday                856
# workingday            1498
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# dtype: int64

# %%
def map_holiday(x):
    #return pd.Series((x['holiday']+1,x['workingday']+2))
    if str(x['holiday']) == 'nan' and  str(x['workingday'])!='nan':
        return  1 if x['workingday']!=1 else 0
    else:
        return x['holiday']
        

df['holiday']=df[['holiday','workingday']].apply(map_holiday,axis=1)

# %%
def map_workingday(x):
    #return pd.Series((x['holiday']+1,x['workingday']+2))
    if str(x['workingday']) == 'nan' and  str(x['holiday'])!='nan':
        return  1 if x['holiday']!=1 else 0
    else:
        return x['workingday']
        

df['workingday']=df[['holiday','workingday']].apply(map_workingday,axis=1)

# %%
df['datetime']=pd.to_datetime(df['datetime'])
df
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 0     2011-01-01  Spring      0.0         0.0   Clear   9.84      81.0
# 1     2011-01-01  Spring      0.0         0.0     NaN   9.02      80.0
# 2     2011-01-01  Spring      0.0         0.0   Clear   9.02       NaN
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 4     2011-01-01     NaN      0.0         0.0   Clear    NaN      75.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10882 2012-12-19  Winter      0.0         1.0     NaN  14.76       NaN
# 10883 2012-12-19     NaN      0.0         1.0   Clear  13.94      61.0
# 10884 2012-12-19  Winter      0.0         1.0   Clear  13.94       NaN
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count
# 0            NaN       3          13                  16
# 1         0.0000       8          32                  40
# 2         0.0000       5          27                  32
# 3         0.0000       3          10                  13
# 4            NaN       0           1                   1
# ...          ...     ...         ...                 ...
# 10881    26.0027       7         329                 336
# 10882        NaN      10         231                 241
# 10883    15.0013       4         164                 168
# 10884     6.0032      12         117                 129
# 10885     8.9981       4          84                  88
#
# [10886 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            10886 non-null  datetime64[ns]
#  1   season              10672 non-null  object
#  2   holiday             10766 non-null  float64
#  3   workingday          10766 non-null  float64
#  4   weather             8746 non-null   object
#  5   temp                8104 non-null   float64
#  6   humidity            7462 non-null   float64
#  7   windspeed           6820 non-null   float64
#  8   casual              10886 non-null  int64
#  9   registered          10886 non-null  int64
#  10  rented_bikes_count  10886 non-null  int64
# dtypes: datetime64[ns](1), float64(5), int64(3), object(2)
# memory usage: 935.6+ KB

# %%
df['datetime'].dt.month
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 10881    12
# 10882    12
# 10883    12
# 10884    12
# 10885    12
# Name: datetime, Length: 10886, dtype: int64

# %%
df['datetime'].dt.day
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 10881    19
# 10882    19
# 10883    19
# 10884    19
# 10885    19
# Name: datetime, Length: 10886, dtype: int64

# %%
df['datetime'].dt.day_name()
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#            ...
# 10881    Wednesday
# 10882    Wednesday
# 10883    Wednesday
# 10884    Wednesday
# 10885    Wednesday
# Name: datetime, Length: 10886, dtype: object

# %%
df[df['season'].isnull()]['season'].loc[4]
# Out:
# nan

# %%
str(df[df['season'].isnull()]['season'].loc[4])
# Out:
# 'nan'

# %%
df['month']=df['datetime'].dt.month
df
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 0     2011-01-01  Spring      0.0         0.0   Clear   9.84      81.0
# 1     2011-01-01  Spring      0.0         0.0     NaN   9.02      80.0
# 2     2011-01-01  Spring      0.0         0.0   Clear   9.02       NaN
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 4     2011-01-01     NaN      0.0         0.0   Clear    NaN      75.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10882 2012-12-19  Winter      0.0         1.0     NaN  14.76       NaN
# 10883 2012-12-19     NaN      0.0         1.0   Clear  13.94      61.0
# 10884 2012-12-19  Winter      0.0         1.0   Clear  13.94       NaN
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month
# 0            NaN       3          13                  16      1
# 1         0.0000       8          32                  40      1
# 2         0.0000       5          27                  32      1
# 3         0.0000       3          10                  13      1
# 4            NaN       0           1                   1      1
# ...          ...     ...         ...                 ...    ...
# 10881    26.0027       7         329                 336     12
# 10882        NaN      10         231                 241     12
# 10883    15.0013       4         164                 168     12
# 10884     6.0032      12         117                 129     12
# 10885     8.9981       4          84                  88     12
#
# [10886 rows x 12 columns]

# %%
df[df['month'].isin([1,2,3])]
# Out:
#        datetime  season  holiday  workingday weather   temp  humidity  \
# 0    2011-01-01  Spring      0.0         0.0   Clear   9.84      81.0
# 1    2011-01-01  Spring      0.0         0.0     NaN   9.02      80.0
# 2    2011-01-01  Spring      0.0         0.0   Clear   9.02       NaN
# 3    2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 4    2011-01-01     NaN      0.0         0.0   Clear    NaN      75.0
# ...         ...     ...      ...         ...     ...    ...       ...
# 6780 2012-03-19  Spring      0.0         1.0   Clear  25.42      61.0
# 6781 2012-03-19  Spring      0.0         1.0     NaN  24.60      64.0
# 6782 2012-03-19  Spring      0.0         1.0   Clear  24.60       NaN
# 6783 2012-03-19  Spring      0.0         1.0    Mist  22.96      73.0
# 6784 2012-03-19  Spring      0.0         1.0    Mist  22.96      78.0
#
#       windspeed  casual  registered  rented_bikes_count  month
# 0           NaN       3          13                  16      1
# 1        0.0000       8          32                  40      1
# 2        0.0000       5          27                  32      1
# 3        0.0000       3          10                  13      1
# 4           NaN       0           1                   1      1
# ...         ...     ...         ...                 ...    ...
# 6780    15.0013      86         463                 549      3
# 6781    15.0013      34         296                 330      3
# 6782    11.0014      33         190                 223      3
# 6783    11.0014      17         131                 148      3
# 6784     8.9981       9          45                  54      3
#
# [2686 rows x 12 columns]

# %%
df[df['season'].isnull()]
# Out:
#         datetime season  holiday  workingday weather   temp  humidity  \
# 4     2011-01-01    NaN      0.0         0.0   Clear    NaN      75.0
# 5     2011-01-01    NaN      0.0         1.0    Mist   9.84       NaN
# 225   2011-01-10    NaN      0.0         1.0   Clear    NaN       NaN
# 244   2011-01-11    NaN      0.0         1.0    Mist   8.20       NaN
# 260   2011-01-12    NaN      0.0         1.0     NaN   5.74      69.0
# ...          ...    ...      ...         ...     ...    ...       ...
# 10498 2012-12-03    NaN      0.0         1.0    Mist  18.86       NaN
# 10508 2012-12-04    NaN      0.0         1.0    Mist  14.76      93.0
# 10644 2012-12-09    NaN      0.0         1.0   Rainy  14.76      93.0
# 10787 2012-12-15    NaN      0.0         0.0   Clear    NaN       NaN
# 10883 2012-12-19    NaN      0.0         1.0   Clear  13.94      61.0
#
#        windspeed  casual  registered  rented_bikes_count  month
# 4            NaN       0           1                   1      1
# 5         6.0032       0           1                   1      1
# 225       8.9981       4          70                  74      1
# 244       6.0032       6          46                  52      1
# 260       8.9981       0          54                  54      1
# ...          ...     ...         ...                 ...    ...
# 10498     0.0000      16         284                 300     12
# 10508     0.0000       3         150                 153     12
# 10644     7.0015       3          75                  78     12
# 10787     8.9981      15         169                 184     12
# 10883    15.0013       4         164                 168     12
#
# [214 rows x 12 columns]

# %%
df.season.unique()
# Out:
# array(['Spring', nan, 'Summer', 'Fall', 'Winter'], dtype=object)

# %%
###### Spring:
# March 3
# April 4
# May 5

### Summer:

# June 6
# July 7
# August 8

### Autumn (Fall):
# September 9
# October 10
# November 11 

### Winter:
# December12
# January 1
# February

# %%
def map_season(x):
    if str(x['season']) == 'nan':
        if x['month'] in ([12,1,2]):
            return 'Winter'
        elif x['month'] in ([3,4,5]):
            return 'Spring'
        elif x['month'] in ([6,7,8]):
            return 'Summer'
        else:
            return 'Fall'
    else:
        return  x['season']
df['season']=df.apply(map_season,axis=1)

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                   0
# holiday                120
# workingday             120
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# month                    0
# dtype: int64

# %%
df['day_name']=df['datetime'].dt.day_name()
df
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 0     2011-01-01  Spring      0.0         0.0   Clear   9.84      81.0
# 1     2011-01-01  Spring      0.0         0.0     NaN   9.02      80.0
# 2     2011-01-01  Spring      0.0         0.0   Clear   9.02       NaN
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 4     2011-01-01  Winter      0.0         0.0   Clear    NaN      75.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10882 2012-12-19  Winter      0.0         1.0     NaN  14.76       NaN
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10884 2012-12-19  Winter      0.0         1.0   Clear  13.94       NaN
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name
# 0            NaN       3          13                  16      1   Saturday
# 1         0.0000       8          32                  40      1   Saturday
# 2         0.0000       5          27                  32      1   Saturday
# 3         0.0000       3          10                  13      1   Saturday
# 4            NaN       0           1                   1      1   Saturday
# ...          ...     ...         ...                 ...    ...        ...
# 10881    26.0027       7         329                 336     12  Wednesday
# 10882        NaN      10         231                 241     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10884     6.0032      12         117                 129     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
# [10886 rows x 13 columns]

# %%
def map_holi_wo(x):
    if str(x['holiday']) == 'nan':
        if x['day_name']=='Saturday' or x['day_name']=='Sunday':
            return pd.Series((1.0,0.0))
        else:
            return pd.Series((0.0,1.0))
    else:
        return pd.Series((x['holiday'],x['workingday']))
    
    
df[['holiday','workingday']]=df.apply(map_holi_wo,axis=1)

# %%
df.isnull().sum()
# Out:
# datetime                 0
# season                   0
# holiday                  0
# workingday               0
# weather               2140
# temp                  2782
# humidity              3424
# windspeed             4066
# casual                   0
# registered               0
# rented_bikes_count       0
# month                    0
# day_name                 0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2809 entries, 3 to 10885
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   datetime            2809 non-null   datetime64[ns]
#  1   season              2809 non-null   object
#  2   holiday             2809 non-null   float64
#  3   workingday          2809 non-null   float64
#  4   weather             2809 non-null   object
#  5   temp                2809 non-null   float64
#  6   humidity            2809 non-null   float64
#  7   windspeed           2809 non-null   float64
#  8   casual              2809 non-null   int64
#  9   registered          2809 non-null   int64
#  10  rented_bikes_count  2809 non-null   int64
#  11  month               2809 non-null   int64
#  12  day_name            2809 non-null   object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(3)
# memory usage: 307.2+ KB

# %%
df.isnull().sum()
# Out:
# datetime              0
# season                0
# holiday               0
# workingday            0
# weather               0
# temp                  0
# humidity              0
# windspeed             0
# casual                0
# registered            0
# rented_bikes_count    0
# month                 0
# day_name              0
# dtype: int64

# %% [markdown]
# # TASK

# %%
# Apply data analysis on 'bikes.csv' dataset.
# here is some questions to think about 
# 1. Make Profit Feature.
#     - Each registerd user rent bike for 5 USD/hour.
#     - Casual user rent bike for 20 USD/hour.
#     - Taxes 0.14%.
#     - Maintance 1500/year.
# 2. Distribution rental_bikes_count & profit.
# 3. Profit for each day.
# 4. Which season that has more registeration & profit.
# 5. Which weather condition that has more registeration & profit.
# 6. Correlation between profit & bikes count with all features.
# 7. Rentals during rush hours (7-9 am & 3-5 pm).
# 7. Rentals during workday & holiday.
# 8. Registered or casual is more.
# 9. What is the average of bikes would be registered during the week.
# 10. Schools (9-12) & (2-6) profit.
# 11. Profit in 2011 & saturdays & season fall

# %%
df[['casual','registered']]
# Out:
#        casual  registered
# 3           3          10
# 11         26          30
# 14         35          71
# 15         40          70
# 16         41          52
# ...       ...         ...
# 10872      17         147
# 10873      31         169
# 10881       7         329
# 10883       4         164
# 10885       4          84
#
# [2809 rows x 2 columns]

# %%
def profit(x):
    revenue=x['casual']*20 + x['registered']*5
    taxes=0.14 * revenue
    maint=1500/(365*24)
    total_profit=revenue - (taxes+maint)
    
    return total_profit
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 11    2011-01-01  Spring      1.0         0.0   Clear  14.76      81.0
# 14    2011-01-01  Spring      0.0         0.0    Mist  18.86      72.0
# 15    2011-01-01  Spring      0.0         0.0    Mist  18.04      77.0
# 16    2011-01-01  Spring      0.0         0.0    Mist  17.22      82.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10872 2012-12-19  Winter      0.0         1.0   Clear  13.12      70.0
# 10873 2012-12-19  Winter      0.0         1.0   Clear  16.40      54.0
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name  \
# 3         0.0000       3          10                  13      1   Saturday
# 11       19.0012      26          30                  56      1   Saturday
# 14       19.0012      35          71                 106      1   Saturday
# 15       19.9995      40          70                 110      1   Saturday
# 16       19.9995      41          52                  93      1   Saturday
# ...          ...     ...         ...                 ...    ...        ...
# 10872     7.0015      17         147                 164     12  Wednesday
# 10873    15.0013      31         169                 200     12  Wednesday
# 10881    26.0027       7         329                 336     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
#        profit/year       profit
# 3        94.428767    94.428767
# 11      576.028767   576.028767
# 14      907.128767   907.128767
# 15      988.828767   988.828767
# 16      928.628767   928.628767
# ...            ...          ...
# 10872   924.328767   924.328767
# 10873  1259.728767  1259.728767
# 10881  1534.928767  1534.928767
# 10883   773.828767   773.828767
# 10885   429.828767   429.828767
#
# [2809 rows x 15 columns]

# %%
df['profit']=df.apply(profit,axis=1)
df
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 11    2011-01-01  Spring      1.0         0.0   Clear  14.76      81.0
# 14    2011-01-01  Spring      0.0         0.0    Mist  18.86      72.0
# 15    2011-01-01  Spring      0.0         0.0    Mist  18.04      77.0
# 16    2011-01-01  Spring      0.0         0.0    Mist  17.22      82.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10872 2012-12-19  Winter      0.0         1.0   Clear  13.12      70.0
# 10873 2012-12-19  Winter      0.0         1.0   Clear  16.40      54.0
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name  \
# 3         0.0000       3          10                  13      1   Saturday
# 11       19.0012      26          30                  56      1   Saturday
# 14       19.0012      35          71                 106      1   Saturday
# 15       19.9995      40          70                 110      1   Saturday
# 16       19.9995      41          52                  93      1   Saturday
# ...          ...     ...         ...                 ...    ...        ...
# 10872     7.0015      17         147                 164     12  Wednesday
# 10873    15.0013      31         169                 200     12  Wednesday
# 10881    26.0027       7         329                 336     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
#        profit/year       profit
# 3        94.428767    94.428767
# 11      576.028767   576.028767
# 14      907.128767   907.128767
# 15      988.828767   988.828767
# 16      928.628767   928.628767
# ...            ...          ...
# 10872   924.328767   924.328767
# 10873  1259.728767  1259.728767
# 10881  1534.928767  1534.928767
# 10883   773.828767   773.828767
# 10885   429.828767   429.828767
#
# [2809 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'humidity', 'windspeed', 'casual', 'registered', 'rented_bikes_count',
#        'month', 'day_name', 'profit/year', 'profit'],
#       dtype='object')

# %%
df
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 11    2011-01-01  Spring      1.0         0.0   Clear  14.76      81.0
# 14    2011-01-01  Spring      0.0         0.0    Mist  18.86      72.0
# 15    2011-01-01  Spring      0.0         0.0    Mist  18.04      77.0
# 16    2011-01-01  Spring      0.0         0.0    Mist  17.22      82.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10872 2012-12-19  Winter      0.0         1.0   Clear  13.12      70.0
# 10873 2012-12-19  Winter      0.0         1.0   Clear  16.40      54.0
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name  \
# 3         0.0000       3          10                  13      1   Saturday
# 11       19.0012      26          30                  56      1   Saturday
# 14       19.0012      35          71                 106      1   Saturday
# 15       19.9995      40          70                 110      1   Saturday
# 16       19.9995      41          52                  93      1   Saturday
# ...          ...     ...         ...                 ...    ...        ...
# 10872     7.0015      17         147                 164     12  Wednesday
# 10873    15.0013      31         169                 200     12  Wednesday
# 10881    26.0027       7         329                 336     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
#        profit/year       profit
# 3        94.428767    94.428767
# 11      576.028767   576.028767
# 14      907.128767   907.128767
# 15      988.828767   988.828767
# 16      928.628767   928.628767
# ...            ...          ...
# 10872   924.328767   924.328767
# 10873  1259.728767  1259.728767
# 10881  1534.928767  1534.928767
# 10883   773.828767   773.828767
# 10885   429.828767   429.828767
#
# [2809 rows x 15 columns]

# %%
df.weather.unique()
# Out:
# array(['Clear', 'Mist', 'Rainy', 'Snowy'], dtype=object)

# %%
df[['weather','profit/year']].corr()
# Out:
#              profit/year
# profit/year          1.0

# %%
df[['rented_bikes_count','profit']].corr()
# Out:
#                     rented_bikes_count    profit
# rented_bikes_count            1.000000  0.934787
# profit                        0.934787  1.000000

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df['rented_bikes_count'],y=df['profit'])

# %% [markdown]
# # . Profit for each day.

# %%
df[['day_name','profit']]
# Out:
#         day_name       profit
# 3       Saturday    94.428767
# 11      Saturday   576.028767
# 14      Saturday   907.128767
# 15      Saturday   988.828767
# 16      Saturday   928.628767
# ...          ...          ...
# 10872  Wednesday   924.328767
# 10873  Wednesday  1259.728767
# 10881  Wednesday  1534.928767
# 10883  Wednesday   773.828767
# 10885  Wednesday   429.828767
#
# [2809 rows x 2 columns]

# %%
df.groupby('day_name')['profit'].describe()
# Out:
#            count         mean          std       min         25%         50%  \
# day_name
# Friday     390.0  1207.544408  1068.976562  4.128767  305.128767  982.378767
# Monday     430.0  1178.818767  1160.599787  4.128767  211.603767  853.378767
# Saturday   408.0  1704.546904  1774.009602  4.128767  348.128767  975.928767
# Sunday     390.0  1552.492613  1577.798701  4.128767  309.428767  778.128767
# Thursday   398.0  1115.776003  1123.363578  4.128767  175.053767  907.128767
# Tuesday    399.0  1152.131775  1139.230455  4.128767  216.978767  816.828767
# Wednesday  394.0  1117.272168  1092.864006  4.128767  268.578767  810.378767
#
#                    75%          max
# day_name
# Friday     1769.278767  5908.028767
# Monday     1811.203767  5383.428767
# Saturday   2555.103767  7524.828767
# Sunday     2477.703767  6338.028767
# Thursday   1609.103767  5460.828767
# Tuesday    1756.378767  6338.028767
# Wednesday  1725.203767  5185.628767

# %%
dt=df.groupby("day_name")[['profit']].mean().sort_values('profit',ascending=False).reset_index()
dt
# Out:
#     day_name       profit
# 0   Saturday  1704.546904
# 1     Sunday  1552.492613
# 2     Friday  1207.544408
# 3     Monday  1178.818767
# 4    Tuesday  1152.131775
# 5  Wednesday  1117.272168
# 6   Thursday  1115.776003

# %%
sns.barplot(x=df['day_name'],y=df['profit'])

# %%
sns.lineplot(x=df['day_name'],y=df['profit'])

# %%
sns.lineplot(x=df[df['datetime'].dt.year==2011]['datetime'],y=df[df['datetime'].dt.year==2011]['profit'])

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'humidity', 'windspeed', 'casual', 'registered', 'rented_bikes_count',
#        'month', 'day_name', 'profit', 'profit/year'],
#       dtype='object')

# %% [markdown]
# # . Which season that has more registeration & profit.

# %%
df.groupby('season')['profit','registered'].sum()
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#               profit  registered
# season
# Fall    1.193484e+06      124858
# Spring  4.903152e+05       69806
# Summer  1.019231e+06      113738
# Winter  9.197164e+05      127273

# %%
df.groupby('season')[['profit']].sum().sort_values('profit',ascending=False)
# Out:
#               profit
# season
# Fall    1.193484e+06
# Summer  1.019231e+06
# Winter  9.197164e+05
# Spring  4.903152e+05

# %%
df.groupby('season')[['registered']].sum().sort_values('registered',ascending=False)
# Out:
#         registered
# season
# Winter      127273
# Fall        124858
# Summer      113738
# Spring       69806

# %%
df.corr()
# Out:
#                      holiday  workingday      temp  humidity  windspeed  \
# holiday             1.000000   -0.375042  0.012707  0.046200   0.012552
# workingday         -0.375042    1.000000 -0.001169 -0.055496   0.009729
# temp                0.012707   -0.001169  1.000000 -0.075085  -0.010714
# humidity            0.046200   -0.055496 -0.075085  1.000000  -0.325871
# windspeed           0.012552    0.009729 -0.010714 -0.325871   1.000000
# casual              0.065701   -0.283074  0.479988 -0.334089   0.091724
# registered         -0.059787    0.107131  0.309707 -0.259378   0.083577
# rented_bikes_count -0.032098    0.012455  0.389831 -0.307978   0.094897
# month              -0.005121   -0.014583  0.255264  0.208132  -0.181826
# profit              0.012935   -0.131033  0.468090 -0.347734   0.101659
# profit/year         0.012935   -0.131033  0.468090 -0.347734   0.101659
#
#                       casual  registered  rented_bikes_count     month  \
# holiday             0.065701   -0.059787           -0.032098 -0.005121
# workingday         -0.283074    0.107131            0.012455 -0.014583
# temp                0.479988    0.309707            0.389831  0.255264
# humidity           -0.334089   -0.259378           -0.307978  0.208132
# windspeed           0.091724    0.083577            0.094897 -0.181826
# casual              1.000000    0.496322            0.687621  0.105165
# registered          0.496322    1.000000            0.971610  0.169907
# rented_bikes_count  0.687621    0.971610            1.000000  0.170762
# month               0.105165    0.169907            0.170762  1.000000
# profit              0.900685    0.824212            0.934787  0.153631
# profit/year         0.900685    0.824212            0.934787  0.153631
#
#                       profit  profit/year
# holiday             0.012935     0.012935
# workingday         -0.131033    -0.131033
# temp                0.468090     0.468090
# humidity           -0.347734    -0.347734
# windspeed           0.101659     0.101659
# casual              0.900685     0.900685
# registered          0.824212     0.824212
# rented_bikes_count  0.934787     0.934787
# month               0.153631     0.153631
# profit              1.000000     1.000000
# profit/year         1.000000     1.000000

# %%
sns.heatmap(df.corr())

# %%
df[(df['season']=='Winter' )|~(df['datetime'].dt.year==2011) ]
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 608   2011-02-08  Winter      0.0         1.0   Clear   9.84      38.0
# 652   2011-02-10  Winter      0.0         1.0   Clear   4.92      42.0
# 713   2011-02-13  Winter      0.0         0.0   Clear   8.20      59.0
# 4056  2011-10-01  Winter      0.0         0.0   Clear  19.68      67.0
# 4059  2011-10-01  Winter      0.0         0.0   Clear  18.04      58.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10872 2012-12-19  Winter      0.0         1.0   Clear  13.12      70.0
# 10873 2012-12-19  Winter      0.0         1.0   Clear  16.40      54.0
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name  \
# 608      32.9975       2          63                  65      2    Tuesday
# 652      19.9995       1          34                  35      2   Thursday
# 713       6.0032       1          23                  24      2     Sunday
# 4056     22.0028      11          47                  58     10   Saturday
# 4059     27.9993       2           6                   8     10   Saturday
# ...          ...     ...         ...                 ...    ...        ...
# 10872     7.0015      17         147                 164     12  Wednesday
# 10873    15.0013      31         169                 200     12  Wednesday
# 10881    26.0027       7         329                 336     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
#             profit  profit/year
# 608     305.128767   305.128767
# 652     163.228767   163.228767
# 713     115.928767   115.928767
# 4056    391.128767   391.128767
# 4059     60.028767    60.028767
# ...            ...          ...
# 10872   924.328767   924.328767
# 10873  1259.728767  1259.728767
# 10881  1534.928767  1534.928767
# 10883   773.828767   773.828767
# 10885   429.828767   429.828767
#
# [1760 rows x 15 columns]

# %% [markdown]
# # . Rentals during rush hours (7-9 am & 3-5 pm).

# %%
df['datetime'].dt.hour==0
# Out:
# 3        True
# 11       True
# 14       True
# 15       True
# 16       True
#          ...
# 10872    True
# 10873    True
# 10881    True
# 10883    True
# 10885    True
# Name: datetime, Length: 2809, dtype: bool

# %%
df
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 3     2011-01-01  Spring      0.0         0.0   Clear   9.84      75.0
# 11    2011-01-01  Spring      1.0         0.0   Clear  14.76      81.0
# 14    2011-01-01  Spring      0.0         0.0    Mist  18.86      72.0
# 15    2011-01-01  Spring      0.0         0.0    Mist  18.04      77.0
# 16    2011-01-01  Spring      0.0         0.0    Mist  17.22      82.0
# ...          ...     ...      ...         ...     ...    ...       ...
# 10872 2012-12-19  Winter      0.0         1.0   Clear  13.12      70.0
# 10873 2012-12-19  Winter      0.0         1.0   Clear  16.40      54.0
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name  \
# 3         0.0000       3          10                  13      1   Saturday
# 11       19.0012      26          30                  56      1   Saturday
# 14       19.0012      35          71                 106      1   Saturday
# 15       19.9995      40          70                 110      1   Saturday
# 16       19.9995      41          52                  93      1   Saturday
# ...          ...     ...         ...                 ...    ...        ...
# 10872     7.0015      17         147                 164     12  Wednesday
# 10873    15.0013      31         169                 200     12  Wednesday
# 10881    26.0027       7         329                 336     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
#        profit/year
# 3        94.428767
# 11      576.028767
# 14      907.128767
# 15      988.828767
# 16      928.628767
# ...            ...
# 10872   924.328767
# 10873  1259.728767
# 10881  1534.928767
# 10883   773.828767
# 10885   429.828767
#
# [2809 rows x 14 columns]

# %%
df['hour'] = pd.to_datetime(df['datetime']).dt.hour

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'humidity', 'windspeed', 'casual', 'registered', 'rented_bikes_count',
#        'hour', 'month', 'day_name'],
#       dtype='object')

# %%
df.tail()
# Out:
#         datetime  season  holiday  workingday weather   temp  humidity  \
# 10872 2012-12-19  Winter      0.0         1.0   Clear  13.12      70.0
# 10873 2012-12-19  Winter      0.0         1.0   Clear  16.40      54.0
# 10881 2012-12-19  Winter      0.0         1.0   Clear  15.58      50.0
# 10883 2012-12-19  Winter      0.0         1.0   Clear  13.94      61.0
# 10885 2012-12-19  Winter      0.0         1.0   Clear  13.12      66.0
#
#        windspeed  casual  registered  rented_bikes_count  month   day_name  \
# 10872     7.0015      17         147                 164     12  Wednesday
# 10873    15.0013      31         169                 200     12  Wednesday
# 10881    26.0027       7         329                 336     12  Wednesday
# 10883    15.0013       4         164                 168     12  Wednesday
# 10885     8.9981       4          84                  88     12  Wednesday
#
#        profit/year       profit
# 10872   924.328767   924.328767
# 10873  1259.728767  1259.728767
# 10881  1534.928767  1534.928767
# 10883   773.828767   773.828767
# 10885   429.828767   429.828767

# %%
df['hour'] = pd.to_datetime(df.datetime).dt.hour

# %%
df['hour']
# Out:
# 3        0
# 11       0
# 14       0
# 15       0
# 16       0
#         ..
# 10872    0
# 10873    0
# 10881    0
# 10883    0
# 10885    0
# Name: hour, Length: 2809, dtype: int64
